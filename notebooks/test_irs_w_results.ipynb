# %%
import pandas as pd
from scripts.utils.utils.utils import (
    VisualizationHelper
)
past = False
if not past: 
    df_irs = pd.read_csv("../data/export/irs/irs_1_normalize_True_test_results_sigma_0.01_dim_1_8_10_100000_384_epochs_100_bs_64.csv")
else:
    df_irs = pd.read_csv("../data/export/irs/irs_1_normalize_True_test_results_sigma_0.01_dim_1_8_100000_384_epochs_50.csv")

# %%
for i in range(10):
    VisualizationHelper.plot_multiple_series(
        df = df_irs.loc[df_irs.sim==i],
        x = "dt",
        values_column = ["V", "V_est"],
        title = f"Comparison real vs predicted (irs) Path: {i}",
        xlabel = "dt",
        ylabel = "V"
    )
