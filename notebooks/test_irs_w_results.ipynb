# %%
import pandas as pd
from scripts.utils.utils.utils import (
    IRS,
    ZeroBond,
    VisualizationHelper
)
df_irs = pd.read_csv("../data/export/test/irs_1_normalize_True_test_results_sigma_0.01_dim_1_8_100000_384_epochs_50.csv")
# Out:
# 2023-12-13 08:36:56.026943: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
for i in range(10):
    VisualizationHelper.plot_multiple_series(
        df = df_irs.loc[df_irs.sim==i],
        x = "dt",
        values_column = ["V", "V_est"],
        title = f"Comparison real vs predicted (irs) Path: {i}",
        xlabel = "dt",
        ylabel = "V"
    )
