# %%
import pandas as pd
df_zbc = pd.read_csv("../data/export/zerobond/zerobond_1_normalize_True_test_results_sigma_0.01_dim_1_8_100000_384_epochs_10.csv")

# %%
from scripts.utils.utils.utils import (
    VisualizationHelper
)
for i in range(1):
    VisualizationHelper.plot_multiple_series(
        df = df_zbc.loc[df_zbc.sim==i],
        x = "dt",
        values_column = ["V", "V_est"],
        title = f"Comparison real vs predicted (zerobond) Path: {i}",
        xlabel = "dt",
        ylabel = "V"
    )
