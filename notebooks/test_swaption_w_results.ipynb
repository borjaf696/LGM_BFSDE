# %%
import pandas as pd
df_swaption = pd.read_csv("../data/export/swaption/swaption_1_normalize_True_test_results_sigma_0.01_dim_1_8_100000_384_epochs_50.csv")

# %%
from scripts.utils.utils.utils import (
    VisualizationHelper
)
for i in range(10):
    VisualizationHelper.plot_multiple_series(
        df = df_swaption.loc[df_swaption.sim==i],
        x = "dt",
        values_column = ["V", "V_est"],
        title = f"Comparison real vs predicted (swaption) Path: {i}",
        xlabel = "dt",
        ylabel = "V"
    )
